# %%
# visualization
# %matplotlib inline
import seaborn as sns
sns.set_style('whitegrid')
import matplotlib.pyplot as plt

# %%
bernoulli_h= ['sigmoid','exponential','gaussian']

# %%
bernoulli_auc= [
[0.7592900575376679, 0.7620091469978988, 0.9174675224678228, 0.7917206424713487],
[0.6267326463047902, 0.6297563275397396, 0.6989351580386964, 0.5817258571829703],
[0.5875562635917666,0.570866960182346, 0.6197003860804863, 0.7129737777872162]
]

# %%
sns_plot = sns.boxplot(x=bernoulli_h, y=bernoulli_auc);
plt.title("Comparison of Bernoulli models for link prediction")
plt.xlabel("Bernoulli model")
plt.ylabel("AUC")
sns_plot.figure.savefig("plots\ber_auc.png")

# %%
bernoulli_f1_micro= [
[0.22434607645875249, 0.20853080568720378, 0.47959183673469385, 0.728813559322034],
[0.18712273641851107, 0.1611251777571749, 0.4959183673469388,  0.71186440677966],
[0.22032193158953722,0.21327014218009477, 0.5020408163265306, 0.6949152542372881]
]

# %%
sns_plot = sns.boxplot(x=bernoulli_h, y=bernoulli_f1_micro);
plt.title("Comparison of Bernoulli models for node classification")
plt.xlabel("Bernoulli model")
plt.ylabel("F1-micro")
sns_plot.figure.savefig("ber_f1.png")
